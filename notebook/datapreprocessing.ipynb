# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt

db_user = "deepakachyutha" 
connection_str = f"postgresql://{db_user}@localhost:5432/uscrashdata"
engine = create_engine(connection_str)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Weather_Encoded'] = le.fit_transform(df['Weather_Condition'].astype(str))

print(df[['Weather_Condition', 'Weather_Encoded']].head())
# Out:
#   Weather_Condition  Weather_Encoded
# 0              Rain               95
# 1        Light Rain               62
# 2        Light Rain               62
# 3              Rain               95
# 4              Rain               95

# %%
import pandas as pd
from sqlalchemy import create_engine
from sklearn.preprocessing import LabelEncoder


db_connection_str = "postgresql://deepakachyutha@localhost:5432/uscrashdata"
engine = create_engine(db_connection_str)

print("Loading Weather Data from SQL...")

df = pd.read_sql('SELECT "Weather_Condition" FROM processed_accidents LIMIT 10000;', engine)


print("⚙️ Encoding Weather...")
le = LabelEncoder()

df['Weather_Encoded'] = le.fit_transform(df['Weather_Condition'].astype(str))

print("\nSuccess! Here is the comparison:")
print(df.head(10))
# Out:
# 📥 Loading Weather Data from SQL...
# ⚙️ Encoding Weather...
#
# ✅ Success! Here is the comparison:
#   Weather_Condition  Weather_Encoded
# 0     Partly Cloudy               21
# 1     Partly Cloudy               21
# 2              Fair                5
# 3              Fair                5
# 4     Partly Cloudy               21
# 5     Partly Cloudy               21
# 6     Mostly Cloudy               19
# 7     Mostly Cloudy               19
# 8              Fair                5
# 9              Fair                5
